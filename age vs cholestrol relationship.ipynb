# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heart_disease_uci.csv")

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
# now starting visualizing the graph
# let us plot the relationship between age and cholestrol level

fig,axs = plt.subplots()
# axs.scatter(df["age"].values,df["chol"].values) #values krne se yeh numpy values main change hogye

axs.scatter(df["age"],df["chol"]) #although as a df of pandas it is also valid
plt.show()

# As the graph is not symmetric we can conclude that there isn't any clear relation in between them

# %%
fig,axs = plt.subplots()
axs.scatter(df["age"].values[:10],df["chol"].values[:10]) #values krne se yeh numpy values main change hogye

plt.show()

# shuru ki 10 values lekar hisaab lagaya gya hai!

# %%
# now if we want to plot for the mean of ages  vs their cholestrol level
df_meanByAges = df.groupby("age").mean()
df_meanByAges
# ab har individuakl ki bjayee ages k mean lekar cholestrol , etc ka average lia gya hai
# Out:
#              id    trestbps        chol      thalch   oldpeak        ca  \
# age
# 28   304.000000  130.000000  132.000000  185.000000  0.000000       NaN
# 29   248.000000  130.000000  223.500000  177.333333  0.000000  0.000000
# 30   307.000000  170.000000  237.000000  170.000000  0.000000       NaN
# 31   400.000000  110.000000  244.500000  151.500000  0.750000       NaN
# 32   411.400000  110.600000  241.200000  152.200000  0.140000       NaN
# 33   402.500000  110.000000  272.000000  167.500000  0.500000       NaN
# 34   337.571429  124.142857  163.285714  172.571429  0.128571  0.000000
# 35   353.818182  127.333333  197.454545  159.500000  0.333333  0.000000
# 36   397.166667  123.666667  190.333333  166.500000  0.833333       NaN
# 37   353.909091  127.090909  233.727273  152.909091  0.545455  0.000000
# 38   502.375000  120.000000  143.600000  149.250000  0.700000  0.000000
# 39   307.333333  127.333333  240.923077  150.800000  0.280000  0.000000
# ...

# %%
fig,axs = plt.subplots()
axs.scatter(df_meanByAges.index , df_meanByAges.chol) #values krne se yeh numpy values main change hogye

plt.show()

# The insight im getting is with the passage of time cholestrol barh rha hai!!
